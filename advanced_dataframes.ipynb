# %%
import pandas as pd
import numpy as np
from pydataset import data
from env import host, user, password

# %%
def get_db_url(host,user,password):
    datatable = input('Please enter the database you wish to connect to: ')
    url = f'mysql+pymysql://{user}:{password}@{host}/{datatable}'
    return url

# %%
url = get_db_url(host,user,password)
pd.read_sql('SELECT * FROM employees LIMIT 5 OFFSET 50', url)
# Out:
# Please enter the database you wish to connect to: employees
#    emp_no  birth_date first_name  last_name gender   hire_date
# 0   10051  1953-07-28   Hidefumi      Caine      M  1992-10-15
# 1   10052  1961-02-26     Heping     Nitsch      M  1988-05-21
# 2   10053  1954-09-13     Sanjiv   Zschoche      F  1986-02-04
# 3   10054  1957-04-04     Mayumi  Schueller      M  1995-03-13
# 4   10055  1956-06-06     Georgy     Dredge      M  1992-04-27

# %% [markdown]
# def get_db_url2(host,user,password):
#
#     url = f'mysql+pym1ysql://{user}:{password}@{host}/employees'
#     return url

# %%
url2 = get_db_url2(host,user,password)
pd.read_sql('SELECT * FROM employees LIMIT 5 OFFSET 50', url2)  ##3 If we make a type we get a can't load plugin error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-8ba23e2f4784> in <module>
# ----> 1 url2 = get_db_url2(host,user,password)
#       2 pd.read_sql('SELECT * FROM employees LIMIT 5 OFFSET 50', url2)  ##3 If we make a type we get a can't load plugin error
#
# NameError: name 'get_db_url2' is not defined

# %%
url = get_db_url(host,user,password)
pd.read_sql('SELECCT * FROM employees LIMIT 5 OFFSET 50', url) ##intentional error for error message review
# Out:
# Please enter the database you wish to connect to: employees
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1265                 if not evt_handled:
# -> 1266                     self.dialect.do_execute_no_params(
#    1267                         cursor, statement, context
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute_no_params(self, cursor, statement, context)
#     595     def do_execute_no_params(self, cursor, statement, context=None):
# --> 596         cursor.execute(statement)
#     597
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pymysql/cursors.py in execute(self, query, args)
#     147
# --> 148         result = self._query(query)
# ...

# %% [markdown]
# Question 4: Read the employees and titles tables into two separate DataFrames

# %%
employees_df = pd.read_sql('SELECT * FROM employees', url)
employees_df
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
# ...        ...         ...        ...       ...    ...         ...
# 300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
# 300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
# 300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
# [300024 rows x 6 columns]

# %%
type(employees_df)
# Out:
# pandas.core.frame.DataFrame

# %%
titles_df = pd.read_sql('SELECT * FROM titles', url)
titles_df
# Out:
#         emp_no            title   from_date     to_date
# 0        10001  Senior Engineer  1986-06-26  9999-01-01
# 1        10002            Staff  1996-08-03  9999-01-01
# 2        10003  Senior Engineer  1995-12-03  9999-01-01
# 3        10004         Engineer  1986-12-01  1995-12-01
# 4        10004  Senior Engineer  1995-12-01  9999-01-01
# ...        ...              ...         ...         ...
# 443303  499997         Engineer  1987-08-30  1992-08-29
# 443304  499997  Senior Engineer  1992-08-29  9999-01-01
# 443305  499998     Senior Staff  1998-12-27  9999-01-01
# 443306  499998            Staff  1993-12-27  1998-12-27
# 443307  499999         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 4 columns]

# %% [markdown]
# Question 5: How many rows and columns do you have in each dataframe?

# %%
print(employees_df.shape)
print(titles_df.shape)
# Out:
# (300024, 6)
# (443308, 4)

# %% [markdown]
# Question 6: Display the summary statistics for each dataframe?

# %%
employees_df.describe(include='all')
# Out:
#                emp_no  birth_date first_name last_name  gender   hire_date
# count   300024.000000      300024     300024    300024  300024      300024
# unique            NaN        4750       1275      1637       2        5434
# top               NaN  1952-03-08     Shahab      Baba       M  1985-06-20
# freq              NaN          95        295       226  179973         132
# mean    253321.763392         NaN        NaN       NaN     NaN         NaN
# std     161828.235540         NaN        NaN       NaN     NaN         NaN
# min      10001.000000         NaN        NaN       NaN     NaN         NaN
# 25%      85006.750000         NaN        NaN       NaN     NaN         NaN
# 50%     249987.500000         NaN        NaN       NaN     NaN         NaN
# 75%     424993.250000         NaN        NaN       NaN     NaN         NaN
# max     499999.000000         NaN        NaN       NaN     NaN         NaN

# %%
titles_df.describe(include='all')
# Out:
#                emp_no     title   from_date     to_date
# count   443308.000000    443308      443308      443308
# unique            NaN         7        6393        5888
# top               NaN  Engineer  1998-10-25  9999-01-01
# freq              NaN    115003         132      240124
# mean    253075.034430       NaN         NaN         NaN
# std     161853.292613       NaN         NaN         NaN
# min      10001.000000       NaN         NaN         NaN
# 25%      84855.750000       NaN         NaN         NaN
# 50%     249847.500000       NaN         NaN         NaN
# 75%     424891.250000       NaN         NaN         NaN
# max     499999.000000       NaN         NaN         NaN

# %% [markdown]
# Question 7: How many unique titles are in the titles DataFrame

# %%
len(titles_df['title'].value_counts())
# Out:
# 7

# %% [markdown]
# Question 8: What is the oldest_date in the to_date column?

# %%
titles_df['to_date'].sort_values().head(1) # Oldest to_date date below
# Out:
# 16064    1985-03-01
# Name: to_date, dtype: object

# %% [markdown]
# Question 9: What is the most recent date in the to_date column?

# %%
titles_df['to_date'].sort_values().tail(1) # Most recent to_date below
# Out:
# 443307    9999-01-01
# Name: to_date, dtype: object

# %%
min(titles_df['to_date']) ##some more wizardry
# Out:
# datetime.date(1985, 3, 1)

# %%
max(titles_df['to_date']) ##some more wizardry
# Out:
# datetime.date(9999, 1, 1)

# %%
pd.read_sql('SELECT COUNT(DISTINCT title) FROM titles', url)
# Out:
#    COUNT(DISTINCT title)
# 0                      7

# %%
pd.read_sql("SELECT max(to_date) as most_recent_date FROM titles WHERE to_date NOT LIKE '9999%'", url) ## Using SQL to filter out the current 
## employees that have there to_date's set to 9999-01-01
# Out:
#   most_recent_date
# 0       2002-08-01

# %% [markdown]
# ## Exercises Part II Advanced Dataframes

# %%
users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %% [markdown]
# Question 2: What is the result of using a right join on the DataFrames?

# %%
users.merge(roles, left_on='role_id', right_on='id', how='right', indicator=True)
# Out:
#    id_x name_x  role_id  id_y     name_y      _merge
# 0   1.0    bob      1.0     1      admin        both
# 1   2.0    joe      2.0     2     author        both
# 2   3.0  sally      3.0     3   reviewer        both
# 3   4.0   adam      3.0     3   reviewer        both
# 4   NaN    NaN      NaN     4  commenter  right_only

# %% [markdown]
# Question 3: What is the result of using an outer join on the DataFrames?

# %%
users.merge(roles, left_on='role_id', right_on='id', how='outer', indicator=True)
# Out:
#    id_x name_x  role_id  id_y     name_y      _merge
# 0   1.0    bob      1.0   1.0      admin        both
# 1   2.0    joe      2.0   2.0     author        both
# 2   3.0  sally      3.0   3.0   reviewer        both
# 3   4.0   adam      3.0   3.0   reviewer        both
# 4   5.0   jane      NaN   NaN        NaN   left_only
# 5   6.0   mike      NaN   NaN        NaN   left_only
# 6   NaN    NaN      NaN   4.0  commenter  right_only

# %% [markdown]
# Question 4: What happens if you drop the foreign keys from the DataFrames and try to merge them?

# %%
users.merge(roles, how='outer', indicator=True)
# Out:
#    id       name  role_id      _merge
# 0   1        bob      1.0   left_only
# 1   2        joe      2.0   left_only
# 2   3      sally      3.0   left_only
# 3   4       adam      3.0   left_only
# 4   5       jane      NaN   left_only
# 5   6       mike      NaN   left_only
# 6   1      admin      NaN  right_only
# 7   2     author      NaN  right_only
# 8   3   reviewer      NaN  right_only
# 9   4  commenter      NaN  right_only

# %% [markdown]
# # Load the mpg dataset from PyDataset

# %%
mpg = data('mpg')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %% [markdown]
# For Question 7 we can see there are 234 rows and 11 columns after we load the data into our dataframe

# %%
## also can use
mpg.shape
# Out:
# (234, 11)

# %% [markdown]
# Question 8: Check out your column names and perform any cleanup you may want on them.

# %%
data('mpg', show_doc=True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %%
mpg = mpg.rename(columns={'cty': 'city', 'hwy': 'highway', 'displ': 'eng(L)', 'fuelType': 'fuel_type'})
mpg
# Out:
#     manufacturer   model  eng(L)  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4     1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4     1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4     2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4     2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4     2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...     ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat     2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat     2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat     2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat     2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat     3.6  2008    6    auto(s6)   f    17       26  p
#
#        class
# 1    compact
# ...

# %% [markdown]
# Question 9: Display the summary statistics for the dataset

# %%
mpg.describe(include = 'all')  #by using the include all in a describe we have it produce the summary statistics
# for all the columns
# Out:
#        manufacturer        model      eng(L)         year         cyl  \
# count           234          234  234.000000   234.000000  234.000000
# unique           15           38         NaN          NaN         NaN
# top           dodge  caravan 2wd         NaN          NaN         NaN
# freq             37           11         NaN          NaN         NaN
# mean            NaN          NaN    3.471795  2003.500000    5.888889
# std             NaN          NaN    1.291959     4.509646    1.611534
# min             NaN          NaN    1.600000  1999.000000    4.000000
# 25%             NaN          NaN    2.400000  1999.000000    4.000000
# 50%             NaN          NaN    3.300000  2003.500000    6.000000
# 75%             NaN          NaN    4.600000  2008.000000    8.000000
# max             NaN          NaN    7.000000  2008.000000    8.000000
#
#            trans  drv        city     highway   fl class
# count        234  234  234.000000  234.000000  234   234
# ...

# %% [markdown]
# Question 10: How many different vehicle manufacturers are there?

# %%
mpg.manufacturer.value_counts().size
# Out:
# 15

# %%
mpg.manufacturer.agg('nunique')
# Out:
# 15

# %%
mpg.manufacturer.nunique()
# Out:
# 15

# %% [markdown]
# Question 11: How many different models are there?

# %%
mpg.model.value_counts().size
# Out:
# 38

# %%
mpg.model.agg('nunique')
# Out:
# 38

# %%
mpg.model.nunique()
# Out:
# 38

# %% [markdown]
# Questions 12 & 13: Create mileage_difference columns and average_mileage columns for the vehicles

# %%
mpg['average_mileage2'] = mpg[['city','highway']].agg('mean', axis = 1)
mpg
# Out:
#     manufacturer   model  eng(L)  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4     1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4     1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4     2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4     2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4     2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...     ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat     2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat     2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat     2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat     2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat     3.6  2008    6    auto(s6)   f    17       26  p
#
#        class  average_mileage2
# ...

# %%
mpg['mileage_difference'] = mpg.highway - mpg.city
mpg['average_mileage'] = (mpg.city + mpg.highway) / 2
mpg
# Out:
#     manufacturer   model  eng(L)  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4     1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4     1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4     2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4     2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4     2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...     ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat     2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat     2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat     2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat     2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat     3.6  2008    6    auto(s6)   f    17       26  p
#
# ...

# %% [markdown]
# Question 14: Create a column named is_automatic determining if they are automatic or not

# %%
mpg['is_automatic'] = np.where(mpg.trans.str.count('auto'), 'automatic', 'manual')
mpg
# Out:
#     manufacturer   model  eng(L)  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4     1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4     1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4     2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4     2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4     2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...     ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat     2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat     2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat     2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat     2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat     3.6  2008    6    auto(s6)   f    17       26  p
#
# ...

# %%
mpg['is_automatic'] = np.where(mpg.trans.str.count('auto'), True, False)
mpg
# Out:
#     manufacturer   model  eng(L)  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4     1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4     1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4     2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4     2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4     2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...     ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat     2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat     2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat     2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat     2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat     3.6  2008    6    auto(s6)   f    17       26  p
#
# ...

# %% [markdown]
# Question 15: Using the mpg dataset, find out which manufacturer has the best miles per gallon on average?

# %%
mpg.groupby('manufacturer').average_mileage.agg('mean').sort_values(ascending=False)
# Out:
# manufacturer
# honda         28.500000
# volkswagen    25.074074
# hyundai       22.750000
# subaru        22.428571
# audi          22.027778
# toyota        21.720588
# pontiac       21.700000
# nissan        21.346154
# chevrolet     18.447368
# ford          16.680000
# mercury       15.625000
# jeep          15.562500
# dodge         15.540541
# lincoln       14.166667
# land rover    14.000000
# Name: average_mileage, dtype: float64

# %% [markdown]
# Question 16: Do automatic or manual cars have better miles per gallon?

# %%
mpg.groupby('is_automatic').average_mileage.agg('mean').sort_values() #Looks like manual cars are the winners here
# Out:
# is_automatic
# True     19.130573
# False    22.227273
# Name: average_mileage, dtype: float64

# %% [markdown]
# ## Exercise Part III
# -Working with chiptole database

# %%
url = get_db_url(host,user,password)
pd.read_sql('SELECT * FROM orders LIMIT 5 OFFSET 50', url) ##using my new input url function to display orders
## from chipotle
# Out:
# Please enter the database you wish to connect to: chipotle
#    id  order_id  quantity        item_name  \
# 0  51        23         1    Steak Burrito
# 1  52        23         2      Canned Soda
# 2  53        24         1  Chicken Burrito
# 3  54        24         1      Canned Soda
# 4  55        25         1       Steak Bowl
#
#                                                                           choice_description  \
# 0   [Roasted Chili Corn Salsa (Medium), [Rice, Fajita Veggies, Cheese, Sour Cream, Lettuce]]
# 1                                                                             [Mountain Dew]
# 2  [Roasted Chili Corn Salsa (Medium), [Black Beans, Rice, Fajita Veggies, Cheese, Sour C...
# 3                                                                                   [Sprite]
# 4       [Fresh Tomato Salsa (Mild), [Black Beans, Rice, Fajita Veggies, Cheese, Sour Cream]]
#
#   item_price
# 0     $8.99
# 1     $2.18
# 2    $10.98
# 3     $1.09
# 4     $8.99

# %%
orders_df2 = pd.read_sql('SELECT * FROM orders', url)
orders_df2
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# ...

# %% [markdown]
# Question 2: What is the total price for each order?

# %%
orders_df2['item_price'] = orders_df2['item_price'].str.replace('$','').astype(float)
orders_df2
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# ...

# %%
orders_df2.groupby('order_id').sum('item_price')
# Out:
#              id  quantity  item_price  item.price
# order_id
# 1            10         4       11.56       11.56
# 2             5         2       16.98       16.98
# 3            13         2       12.67       12.67
# 4            17         2       21.00       21.00
# 5            21         2       13.70       13.70
# ...         ...       ...         ...         ...
# 1830       9223         2       23.00       23.00
# 1831      13842         3       12.90       12.90
# 1832       9233         2       13.20       13.20
# 1833       9237         2       23.50       23.50
# 1834      13863         3       28.75       28.75
#
# [1834 rows x 4 columns]

# %% [markdown]
# Question 3: What are the 3 most popular items?

# %%
orders_df2.item_name.value_counts().head(3) ##The three most popular items are listed below using
## value counts and the head(3)
# Out:
# Chicken Bowl           726
# Chicken Burrito        553
# Chips and Guacamole    479
# Name: item_name, dtype: int64

# %% [markdown]
# Question 4: Which item has produced the most revenue?

# %%
orders_df2.groupby('item_name').sum('item_price').sort_values(by= 'item_price', ascending = False).head(1)
# Out:
#                    id  order_id  quantity  item_price  item.price
# item_name
# Chicken Bowl  1780635    713926       761     7342.73     7342.73

# %% [markdown]
# Question 5: Using the title DataFrame, visualize the number of employees with each title

# %%
titles_df
# Out:
#         emp_no            title   from_date     to_date
# 0        10001  Senior Engineer  1986-06-26  9999-01-01
# 1        10002            Staff  1996-08-03  9999-01-01
# 2        10003  Senior Engineer  1995-12-03  9999-01-01
# 3        10004         Engineer  1986-12-01  1995-12-01
# 4        10004  Senior Engineer  1995-12-01  9999-01-01
# ...        ...              ...         ...         ...
# 443303  499997         Engineer  1987-08-30  1992-08-29
# 443304  499997  Senior Engineer  1992-08-29  9999-01-01
# 443305  499998     Senior Staff  1998-12-27  9999-01-01
# 443306  499998            Staff  1993-12-27  1998-12-27
# 443307  499999         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 4 columns]

# %%
employees_df
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
# ...        ...         ...        ...       ...    ...         ...
# 300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
# 300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
# 300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
# [300024 rows x 6 columns]

# %%
titles_df['title'].value_counts() ##The number of employees with each title
# Out:
# Engineer              115003
# Staff                 107391
# Senior Engineer        97750
# Senior Staff           92853
# Technique Leader       15159
# Assistant Engineer     15128
# Manager                   24
# Name: title, dtype: int64

# %% [markdown]
# Question 6: Join the employees and titles DataFrames together

# %%
joined_df = titles_df.merge(employees_df, left_on='emp_no', right_on='emp_no', how='inner', indicator=True)
joined_df
# Out:
#         emp_no            title   from_date     to_date  birth_date  \
# 0        10001  Senior Engineer  1986-06-26  9999-01-01  1953-09-02
# 1        10002            Staff  1996-08-03  9999-01-01  1964-06-02
# 2        10003  Senior Engineer  1995-12-03  9999-01-01  1959-12-03
# 3        10004         Engineer  1986-12-01  1995-12-01  1954-05-01
# 4        10004  Senior Engineer  1995-12-01  9999-01-01  1954-05-01
# ...        ...              ...         ...         ...         ...
# 443303  499997         Engineer  1987-08-30  1992-08-29  1961-08-03
# 443304  499997  Senior Engineer  1992-08-29  9999-01-01  1961-08-03
# 443305  499998     Senior Staff  1998-12-27  9999-01-01  1956-09-05
# 443306  499998            Staff  1993-12-27  1998-12-27  1956-09-05
# 443307  499999         Engineer  1997-11-30  9999-01-01  1958-05-01
#
#        first_name last_name gender   hire_date _merge
# 0          Georgi   Facello      M  1986-06-26   both
# ...

# %% [markdown]
# Question 7: Visualize how frequently employees change titles

# %%
pd.crosstab(joined_df.emp_no, joined_df.title, margins =True)
# Out:
# title   Assistant Engineer  Engineer  Manager  Senior Engineer  Senior Staff  \
# emp_no
# 10001                    0         0        0                1             0
# 10002                    0         0        0                0             0
# 10003                    0         0        0                1             0
# 10004                    0         1        0                1             0
# 10005                    0         0        0                0             1
# ...                    ...       ...      ...              ...           ...
# 499996                   0         1        0                1             0
# 499997                   0         1        0                1             0
# 499998                   0         0        0                0             1
# 499999                   0         1        0                0             0
# All                  15128    115003       24            97750         92853
#
# ...

# %%
joined_df.groupby('emp_no').title.count()
# Out:
# emp_no
# 10001     1
# 10002     1
# 10003     1
# 10004     2
# 10005     2
#          ..
# 499995    1
# 499996    2
# 499997    2
# 499998    2
# 499999    1
# Name: title, Length: 300024, dtype: int64

# %% [markdown]
# Question 8: For each title, find the hire date of the employee that was hired most recently with that title

# %%
joined_df.groupby('title').hire_date.max()
# Out:
# title
# Assistant Engineer    1999-12-24
# Engineer              2000-01-28
# Manager               1992-02-05
# Senior Engineer       2000-01-01
# Senior Staff          2000-01-13
# Staff                 2000-01-12
# Technique Leader      1999-12-31
# Name: hire_date, dtype: object

# %% [markdown]
# Question 9: Write the code necessary to create a cross tabulation of the number of titles by department. (Hint: this will involve a combination of SQL code to pull the necessary data and python/pandas code to perform the manipulations.)

# %%
sql_query = '''
SELECT *
FROM employees as e
JOIN titles as t USING(emp_no)
JOIN dept_emp as de USING(emp_no)
JOIN departments as d USING(dept_no);
'''

the_big_df = pd.read_sql(sql_query, get_db_url(host,user,password))
# Out:
# Please enter the database you wish to connect to: employees

# %%
the_big_df
# Out:
#        dept_no  emp_no  birth_date first_name last_name gender   hire_date  \
# 0         d009   10011  1953-11-07       Mary     Sluis      F  1990-01-22
# 1         d009   10038  1960-07-20       Huan     Lortz      M  1989-09-20
# 2         d009   10038  1960-07-20       Huan     Lortz      M  1989-09-20
# 3         d009   10049  1961-04-24      Basil    Tramer      F  1992-05-04
# 4         d009   10049  1961-04-24      Basil    Tramer      F  1992-05-04
# ...        ...     ...         ...        ...       ...    ...         ...
# 489898    d007  499986  1952-07-22     Nathan     Ranta      F  1985-08-11
# 489899    d007  499986  1952-07-22     Nathan     Ranta      F  1985-08-11
# 489900    d007  499987  1961-09-05      Rimli    Dusink      F  1998-09-20
# 489901    d007  499988  1962-09-28   Bangqing   Kleiser      F  1986-06-06
# 489902    d007  499988  1962-09-28   Bangqing   Kleiser      F  1986-06-06
#
# ...

# %%
pd.crosstab(the_big_df.title, the_big_df.dept_name)
# Out:
# dept_name           Customer Service  Development  Finance  Human Resources  \
# title
# Assistant Engineer               298         7769        0                0
# Engineer                        2362        58135        0                0
# Manager                            4            2        2                2
# Senior Engineer                 2027        49326        0                0
# Senior Staff                   13925         1247    12139            12274
# Staff                          16150         1424    13929            14342
# Technique Leader                 309         7683        0                0
#
# dept_name           Marketing  Production  Quality Management  Research  Sales
# title
# Assistant Engineer          0        6445                1831       378      0
# Engineer                    0       49649               13852      2986      0
# Manager                     2           4                   4         2      2
# ...
